# %%
import pandas as pd

# %%
# Import methods 
import sys
sys.path.append("..")
from methods.dataframe_methods import clean_columns

# %%
# Set column display options
pd.set_option("display.max_columns", None)

# %%
bfro_locations_file = "https://raw.githubusercontent.com/kkruel8100/paranormal/main/resources/bfro_locations.csv"
bfro_reports_file = "https://raw.githubusercontent.com/kkruel8100/paranormal/main/resources/bfro_reports.csv"
bfro_reports_geocoded_file = "https://raw.githubusercontent.com/kkruel8100/paranormal/main/resources/bfro_reports_geocoded.csv"
ufo_file = "https://raw.githubusercontent.com/kkruel8100/paranormal/main/resources/ufo-sightings-transformed.csv"

# %%
bfro_locations_df = pd.read_csv(bfro_locations_file).copy()
bfro_reports_df = pd.read_csv(bfro_reports_file).copy()
bfro_reports_geocoded_df = pd.read_csv(bfro_reports_geocoded_file).copy()
ufo_df = pd.read_csv(ufo_file).copy()

# %%
bfro_locations_df = clean_columns(bfro_locations_df)
display(bfro_locations_df.head())
# Out:
#    index  number                                              title  \
# 0      0     637  Report 637: Campers' encounter just after dark...
# 1      1    2917  Report 2917: Family observes large biped from car
# 2      2    7963  Report 7963: Sasquatch walks past window of ho...
# 3      3    9317  Report 9317: Driver on Alcan Highway has noon,...
# 4      4   13038  Report 13038: Snowmobiler has encounter in dee...
#
#   classification             timestamp  latitude  longitude
# 0        Class A  2000-06-16T12:00:00Z   61.5000  -142.9000
# 1        Class A  1995-05-15T12:00:00Z   55.1872  -132.7982
# 2        Class A  2004-02-09T12:00:00Z   55.2035  -132.8202
# 3        Class A  2004-06-18T12:00:00Z   62.9375  -141.5667
# 4        Class A  2004-02-15T12:00:00Z   61.0595  -149.7853

# %%
bfro_reports_df = clean_columns(bfro_reports_df)
display(bfro_reports_df.head())
# Out:
#    index          year  season         state                          county  \
# 0      0          2010  Summer       Alabama                  Winston County
# 1      1  Early 1990's    Fall        Alaska  Valdez-Chitina-Whittier County
# 2      2          1974    Fall  Rhode Island               Washington County
# 3      3      72 or 73  Summer  Pennsylvania                     York County
# 4      4          1984  Spring        Oregon                  Yamhill County
#
#                               nearest_town   nearest_road  \
# 0                           Double Springs     Highway 33
# 1                                      NaN            NaN
# 2                                Wakefield     Perry Ave.
# 3  York; more specifically Manchester twp.  Raintree Road
# 4                                  Yamhill    NW Fairdale
#
#                                             observed  \
# 0  I was canoeing on the Sipsey river in Alabama....
# ...

# %%
bfro_reports_geocoded_df = clean_columns(bfro_reports_geocoded_df)
display(bfro_reports_geocoded_df.head())
# Out:
#    index                                           observed  \
# 0      0  I was canoeing on the Sipsey river in Alabama....
# 1      1  Ed L. was salmon fishing with a companion in P...
# 2      2  While attending U.R.I in the Fall of 1974,I wo...
# 3      3  Hello, My name is Doug and though I am very re...
# 4      4  It was May 1984. Two friends and I were up in ...
#
#                                     location_details  \
# 0                                                NaN
# 1                  East side of Prince William Sound
# 2             Great swamp area, Narragansett Indians
# 3  I would rather not have exact location (listin...
# 4  Logging roads north west of Yamhill, OR, about...
#
#                            county         state  season  \
# 0                  Winston County       Alabama  Summer
# 1  Valdez-Chitina-Whittier County        Alaska    Fall
# 2               Washington County  Rhode Island    Fall
# ...

# %%
ufo_df = clean_columns(ufo_df)
display(ufo_df.head())
# Out:
#    unnamed:_0            date_time date_documented  year  month  hour  season  \
# 0           0  1949-10-10 20:30:00       4/27/2004  1949     10    20  Autumn
# 1           1  1949-10-10 21:00:00      12/16/2005  1949     10    21  Autumn
# 2           2  1955-10-10 17:00:00       1/21/2008  1955     10    17  Autumn
# 3           3  1956-10-10 21:00:00       1/17/2004  1956     10    21  Autumn
# 4           4  1960-10-10 20:00:00       1/22/2004  1960     10    20  Autumn
#
#   country_code         country   region        locale   latitude   longitude  \
# 0          USA   United States    Texas    San Marcos  29.883056  -97.941111
# 1          USA   United States    Texas  Bexar County  29.384210  -98.581082
# 2          GBR  United Kingdom  England       Chester  53.200000   -2.916667
# 3          USA   United States    Texas          Edna  28.978333  -96.645833
# 4          USA   United States   Hawaii       Kaneohe  21.418056 -157.803611
#
# ...
